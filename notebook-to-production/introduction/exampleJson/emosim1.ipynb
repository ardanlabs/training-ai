// %% [markdown]
// # EmoSim508

// %% [markdown]
// An Emoji Similarity Baseline Dataset with 508 Emoji Pairs and Similarity Ratings. From https://www.kaggle.com/sanjayaw/emosim508

// %%
import "fmt"
import "encoding/json"
import "io/ioutil"
import "strings"

// %% [markdown]
// ## 1. Create json structure to handle data

// %%
type emoji struct{
    Unicodelong string `json:"unicodelong"`
    Unicodeshort string `json:"unicodeshort"`
    Title string `json:"title"`
}

type emojiTuple struct{
    EmojiOne emoji `json:"emojiOne"`
    EmojiTwo emoji `json:"emojiTwo"`
}

type emojiSimilarityMetrics struct{
    Google_Sense_Label float64
    Twitter_Sense_Def float64
    Google_Sense_All float64
    Google_Sense_Def float64
    Google_Sense_Desc float64
    Twitter_Sense_All float64
    Twitter_Sense_Desc float64
    Twitter_Sense_Label float64
    Human_Annotator_Agreement float64
}

type emojiSim struct{
    EmojiPairId string `json:"emojiPairId"`
    EmojiPair emojiTuple `json:"emojiPair"`
    EmojiPairSimilarity emojiSimilarityMetrics `json:"emojiPairSimilarity"`
}

// %% [markdown]
// ## 2. load json file

// %%
file, err := ioutil.ReadFile("../data/EmoSim508.json")

// %%
fmt.Println(err)
// Out:
// <nil>
// 6 <nil>

// %%
var emojisims []emojiSim

// %%
err = json.Unmarshal(file, &emojisims)

// %%
fmt.Println(err)
// Out:
// <nil>
// 6 <nil>

// %%
fmt.Println(emojisims)
// Out:
// [{199 {{\U0001F3B5 U+1F3B5 musical note} {\U0001F3B6 U+1F3B6 musical notes}} {0.94 1 1 1 0.84 1 0.89 0.92 4}} {66 {{\U0001F38A U+1F38A confetti ball} {\U0001F389 U+1F389 party popper}} {0.84 0.95 0.95 0.94 0.78 0.96 0.77 0.84 3.95}} {483 {{\U0000263A U+263A smiling face} {\U0001F60A U+1F60A smiling face with smiling eyes}} {0.94 0.99 0.99 0.99 0.58 0.99 0.65 0.95 3.9}} {218 {{\U00002764 U+2764 red heart} {\U0001F49E U+1F49E revolving hearts}} {0.9 0.98 0.98 0.98 0.71 0.98 0.82 0.89 3.85}} {23 {{\U0001F495 U+1F495 two hearts} {\U00002764 U+2764 red heart}} {0.92 0.99 0.99 0.99 0.78 0.99 0.84 0.91 3.85}} {151 {{\U0001F49E U+1F49E revolving hearts} {\U0001F495 U+1F495 two hearts}} {0.96 0.99 0.99 0.99 0.82 0.99 0.83 0.96 3.85}} {287 {{\U0001F498 U+1F498 heart with arrow} {\U0001F495 U+1F495 two hearts}} {0.91 0.99 0.98 0.99 0.7 0.99 0.68 0.87 3.85}} {10 {{\U0001F495 U+1F495 two hearts} {\U0001F60D U+1F60D smiling face with heart-eyes}} {0.87 0.97 0.96 0.96 0.79 0.97 0.81 0.84 3.8}} {125 {{\U0001F49C U+1F49C purple heart} {\U0001F499 U+1F499 blue heart}} {0.87 0.98 0.98 0.98 0.87 0.98 0.93 0.82 3.8}} {241 {{\U0001F497 U+1F497 growing heart} {\U00002764 U+2764 red heart}} {0.9 0.98 0.98 0.98 0.76 0.98 0.8 0.87 3.8}} {278 {{\U0001F497 U+1F497 growing heart} {\U0001F495 U+1F495 two hearts}} {0.91 0.99 0.98 0.98 0.71 0.99 0.77 0.87 3.8}} {375 {{\U00002764 U+2764 red heart} {\U0001F493 U+1F493 beating heart}} {0.92 0.99 0.98 0.99 0.74 0.98 0.8 0.9 3.8}} {51 {{\U0001F3A4 U+1F3A4 microphone} {\U0001F3B6 U+1F3B6 musical notes}} {0.7 0.95 0.93 0.93 0.77 0.95 0.78 0.71 3.75}} {102 {{\U0001F496 U+1F496 sparkling heart} {\U0001F495 U+1F495 two hearts}} {0.9 0.98 0.98 0.98 0.78 0.98 0.79 0.86 3.75}} {323 {{\U0001F495 U+1F495 two hearts} {\U0001F493 U+1F493 beating heart}} {0.95 1 0.99 1 0.73 0.99 0.76 0.97 3.75}} {63 {{\U00002764 U+2764 red heart} {\U0001F499 U+1F499 blue heart}} {0.86 0.98 0.98 0.98 0.68 0.98 0.76 0.84 3.7}} {120 {{\U0001F499 U+1F499 blue heart} {\U0001F49A U+1F49A green heart}} {0.9 0.98 0.98 0.98 0.74 0.98 0.78 0.89 3.7}} {129 {{\U00002764 U+2764 red heart} {\U0001F49C U+1F49C purple heart}} {0.89 0.98 0.98 0.98 0.68 0.98 0.75 0.85 3.7}} {130 {{\U0001F49B U+1F49B yellow heart} {\U0001F49A U+1F49A green heart}} {0.92 0.97 0.97 0.97 0.87 0.98 0.9 0.85 3.7}} {132 {{\U00002764 U+2764 red heart} {\U0001F496 U+1F496 sparkling heart}} {0.9 0.98 0.98 0.98 0.8 0.98 0.78 0.88 3.7}} {148 {{\U00002764 U+2764 red heart} {\U0001F49A U+1F49A green heart}} {0.91 0.97 0.97 0.97 0.77 0.97 0.82 0.9 3.7}} {155 {{\U0001F49B U+1F49B yellow heart} {\U00002764 U+2764 red heart}} {0.86 0.97 0.98 0.98 0.84 0.98 0.85 0.8 3.7}} {179 {{\U0001F49C U+1F49C purple heart} {\U0001F49A U+1F49A green heart}} {0.88 0.97 0.97 0.97 0.8 0.97 0.83 0.82 3.7}} {195 {{\U0001F49B U+1F49B yellow heart} {\U0001F49C U+1F49C purple heart}} {0.86 0.98 0.98 0.98 0.82 0.98 0.84 0.82 3.7}} {284 {{\U0001F49E U+1F49E revolving hearts} {\U0001F496 U+1F496 sparkling heart}} {0.89 0.98 0.98 0.98 0.74 0.98 0.78 0.86 3.7}} {408 {{\U0001F497 U+1F497 growing heart} {\U0001F496 U+1F496 sparkling heart}} {0.91 0.98 0.97 0.98 0.75 0.98 0.8 0.89 3.65}} {60 {{\U0001F3A7 U+1F3A7 headphone} {\U0001F3B6 U+1F3B6 musical notes}} {0.79 0.93 0.91 0.92 0.64 0.93 0.69 0.83 3.6}} {55 {{\U0001F60D U+1F60D smiling face with heart-eyes} {\U0001F496 U+1F496 sparkling heart}} {0.86 0.97 0.97 0.97 0.78 0.97 0.76 0.87 3.55}} {98 {{\U0001F3CC U+1F3CC person golfing} {\U000026F3 U+26F3 flag in hole}} {0.77 0.98 0.97 0.97 0.8 0.98 0.86 0.81 3.55}} {286 {{\U0001F495 U+1F495 two hearts} {\U0001F49C U+1F49C purple heart}} {0.9 0.99 0.98 0.98 0.62 0.98 0.78 0.84 3.55}} {465 {{\U0001F3BC U+1F3BC musical score} {\U0001F3B6 U+1F3B6 musical notes}} {0.88 0.98 0.97 0.97 0.66 0.98 0.69 0.84 3.55}} {3 {{\U00002764 U+2764 red heart} {\U0001F60D U+1F60D smiling face with heart-eyes}} {0.88 0.97 0.97 0.97 0.79 0.97 0.86 0.89 3.5}} {134 {{\U0001F60D U+1F60D smiling face with heart-eyes} {\U0001F49E U+1F49E revolving hearts} ...
// udspeaker} {\U000026A0 U+26A0 warning}} {0.34 0.87 0.75 0.75 0.69 0.87 0.75 0.59 0.65}} {190 {{\U0001F4E2 U+1F4E2 loudspeaker} {\U0001F6A9 U+1F6A9 triangular flag}} {0.18 0.85 0.72 0.74 0.59 0.85 0.59 0.34 0.65}} {223 {{\U0001F451 U+1F451 crown} {\U0001F495 U+1F495 two hearts}} {0.34 0.84 0.73 0.75 0.58 0.82 0.61 0.39 0.65}} {303 {{\U0001F602 U+1F602 face with tears of joy} {\U0001F49C U+1F49C purple heart}} {0.59 0.9 0.86 0.87 0.49 0.9 0.63 0.63 0.65}} {308 {{\U00002728 U+2728 sparkles} {\U0001F49E U+1F49E revolving hearts}} {0.36 0.81 0.73 0.73 0.61 0.81 0.55 0.37 0.65}} {341 {{\U00002764 U+2764 red heart} {\U0001F3B6 U+1F3B6 musical notes}} {0.42 0.83 0.78 0.8 0.61 0.82 0.7 0.43 0.65}} {353 {{\U0001F495 U+1F495 two hearts} {\U0001F338 U+1F338 cherry blossom}} {0.3 0.81 0.72 0.72 0.64 0.8 0.61 0.25 0.65}} {421 {{\U0001F4AF U+1F4AF hundred points} {\U0001F44F U+1F44F clapping hands}} {0.13 0.81 0.74 0.74 0.62 0.8 0.66 0.35 0.65}} {336 {{\U0001F449 U+1F449 backhand index pointing right} {\U00002714 U+2714 heavy check mark}} {0.27 0.81 0.75 0.72 0.59 0.82 0.66 0.36 0.65}} {348 {{\U00002728 U+2728 sparkles} {\U0001F499 U+1F499 blue heart}} {0.39 0.84 0.76 0.76 0.57 0.83 0.53 0.41 0.6}} {376 {{\U0001F31F U+1F31F glowing star} {\U00002764 U+2764 red heart}} {0.45 0.8 0.78 0.78 0.72 0.8 0.78 0.51 0.6}} {398 {{\U0001F62D U+1F62D loudly crying face} {\U0001F605 U+1F605 smiling face with open mouth & cold sweat}} {0.6 0.92 0.89 0.9 0.74 0.91 0.75 0.61 0.6}} {405 {{\U0001F618 U+1F618 face blowing a kiss} {\U0001F648 U+1F648 see-no-evil monkey}} {0.54 0.9 0.83 0.83 0.72 0.89 0.7 0.6 0.6}} {478 {{\U0001F49A U+1F49A green heart} {\U00002728 U+2728 sparkles}} {0.41 0.81 0.73 0.72 0.67 0.81 0.61 0.4 0.6}} {6 {{\U0001F644 U+1F644 face with rolling eyes} {\U0001F602 U+1F602 face with tears of joy}} {0.31 0.88 0.82 0.81 0.63 0.89 0.65 0.42 0.6}} {18 {{\U0001F633 U+1F633 flushed face} {\U0001F602 U+1F602 face with tears of joy}} {0.64 0.92 0.89 0.89 0.68 0.92 0.7 0.65 0.6}} {113 {{\U0001F602 U+1F602 face with tears of joy} {\U0001F612 U+1F612 unamused face}} {0.61 0.9 0.87 0.87 0.76 0.9 0.74 0.65 0.6}} {114 {{\U0001F62D U+1F62D loudly crying face} {\U0001F618 U+1F618 face blowing a kiss}} {0.53 0.86 0.81 0.82 0.68 0.85 0.72 0.53 0.6}} {152 {{\U0001F648 U+1F648 see-no-evil monkey} {\U00002764 U+2764 red heart}} {0.53 0.9 0.86 0.86 0.65 0.9 0.69 0.58 0.6}} {176 {{\U0001F64C U+1F64C raising hands} {\U00002764 U+2764 red heart}} {0.58 0.92 0.89 0.9 0.59 0.92 0.61 0.55 0.6}} {201 {{\U0001F631 U+1F631 face screaming in fear} {\U0001F60D U+1F60D smiling face with heart-eyes}} {0.53 0.91 0.89 0.9 0.75 0.91 0.73 0.63 0.6}} {202 {{\U0001F44F U+1F44F clapping hands} {\U0001F449 U+1F449 backhand index pointing right}} {0.37 0.92 0.88 0.89 0.62 0.92 0.72 0.57 0.6}} {206 {{\U0001F64A U+1F64A speak-no-evil monkey} {\U0001F60D U+1F60D smiling face with heart-eyes}} {0.52 0.92 0.88 0.89 0.72 0.91 0.69 0.62 0.6}} {215 {{\U0001F64F U+1F64F folded hands} {\U0001F60A U+1F60A smiling face with smiling eyes}} {0.55 0.91 0.87 0.88 0.55 0.91 0.6 0.61 0.6}} {225 {{\U0001F4AF U+1F4AF hundred points} {\U0000203C U+203C double exclamation mark}} {0.22 0.87 0.83 0.83 0.63 0.87 0.69 0.28 0.6}} {354 {{\U0001F602 U+1F602 face with tears of joy} {\U0001F497 U+1F497 growing heart}} {0.62 0.91 0.88 0.88 0.57 0.9 0.63 0.64 0.6}} {369 {{\U0001F4CD U+1F4CD round pushpin} {\U0001F3AF U+1F3AF direct hit}} {0.41 0.86 0.83 0.83 0.63 0.86 0.72 0.47 0.6}} {371 {{\U0001F60E U+1F60E smiling face with sunglasses} {\U0001F4AF U+1F4AF hundred points}} {0.31 0.84 0.78 0.79 0.55 0.82 0.6 0.33 0.6}} {435 {{\U0001F44B U+1F44B waving hand} {\U0001F618 U+1F618 face blowing a kiss}} {0.55 0.9 0.83 0.84 0.68 0.89 0.67 0.55 0.6}} {493 {{\U00002728 U+2728 sparkles} {\U0001F451 U+1F451 crown}} {0.28 0.78 0.65 0.65 0.61 0.77 0.56 0.33 0.6}} {507 {{\U0001F608 U+1F608 smiling face with horns} {\U0001F60D U+1F60D smiling face with heart-eyes}} {0.66 0.91 0.88 0.88 0.71 0.91 0.74 0.71 0.6}} {16 {{\U0001F4AF U ...
// 65398 <nil>

// %% [markdown]
// ## 3. Process data

// %% [markdown]
// #### select all the pair where le Human_Annotator_Agreement is greater than 3.5, meaning that the emojis are very  similar (0-4)

// %% [markdown]
// and stock only the emoji tuple

// %%
var resultPairs []emojiTuple

for _,val := range emojisims {
    if val.EmojiPairSimilarity.Human_Annotator_Agreement>3.5{
        resultPairs = append(resultPairs,val.EmojiPair)
    }
}

// %%
fmt.Println(len(resultPairs))
// Out:
// 31
// 3 <nil>

// %% [markdown]
// #### save data to a file

// %%
jsonString, err := json.Marshal(resultPairs)

// %%
fmt.Println(string(jsonString))
// Out:
// [{"EmojiOne":{"Unicodelong":"\\U0001F3B5","Unicodeshort":"U+1F3B5","Title":"musical note"},"EmojiTwo":{"Unicodelong":"\\U0001F3B6","Unicodeshort":"U+1F3B6","Title":"musical notes"}},{"EmojiOne":{"Unicodelong":"\\U0001F38A","Unicodeshort":"U+1F38A","Title":"confetti ball"},"EmojiTwo":{"Unicodelong":"\\U0001F389","Unicodeshort":"U+1F389","Title":"party popper"}},{"EmojiOne":{"Unicodelong":"\\U0000263A","Unicodeshort":"U+263A","Title":"smiling face"},"EmojiTwo":{"Unicodelong":"\\U0001F60A","Unicodeshort":"U+1F60A","Title":"smiling face with smiling eyes"}},{"EmojiOne":{"Unicodelong":"\\U00002764","Unicodeshort":"U+2764","Title":"red heart"},"EmojiTwo":{"Unicodelong":"\\U0001F49E","Unicodeshort":"U+1F49E","Title":"revolving hearts"}},{"EmojiOne":{"Unicodelong":"\\U0001F495","Unicodeshort":"U+1F495","Title":"two hearts"},"EmojiTwo":{"Unicodelong":"\\U00002764","Unicodeshort":"U+2764","Title":"red heart"}},{"EmojiOne":{"Unicodelong":"\\U0001F49E","Unicodeshort":"U+1F49E","Title":"revolving hearts"},"EmojiTwo":{"Unicodelong":"\\U0001F495","Unicodeshort":"U+1F495","Title":"two hearts"}},{"EmojiOne":{"Unicodelong":"\\U0001F498","Unicodeshort":"U+1F498","Title":"heart with arrow"},"EmojiTwo":{"Unicodelong":"\\U0001F495","Unicodeshort":"U+1F495","Title":"two hearts"}},{"EmojiOne":{"Unicodelong":"\\U0001F495","Unicodeshort":"U+1F495","Title":"two hearts"},"EmojiTwo":{"Unicodelong":"\\U0001F60D","Unicodeshort":"U+1F60D","Title":"smiling face with heart-eyes"}},{"EmojiOne":{"Unicodelong":"\\U0001F49C","Unicodeshort":"U+1F49C","Title":"purple heart"},"EmojiTwo":{"Unicodelong":"\\U0001F499","Unicodeshort":"U+1F499","Title":"blue heart"}},{"EmojiOne":{"Unicodelong":"\\U0001F497","Unicodeshort":"U+1F497","Title":"growing heart"},"EmojiTwo":{"Unicodelong":"\\U00002764","Unicodeshort":"U+2764","Title":"red heart"}},{"EmojiOne":{"Unicodelong":"\\U0001F497","Unicodeshort":"U+1F497","Title":"growing heart"},"EmojiTwo":{"Unicodelong":"\\U0001F495","Unicodeshort":"U+1F495","Title":"two hearts"}},{"EmojiOne":{"Unicodelong":"\\U00002764","Unicodeshort":"U+2764","Title":"red heart"},"EmojiTwo":{"Unicodelong":"\\U0001F493","Unicodeshort":"U+1F493","Title":"beating heart"}},{"EmojiOne":{"Unicodelong":"\\U0001F3A4","Unicodeshort":"U+1F3A4","Title":"microphone"},"EmojiTwo":{"Unicodelong":"\\U0001F3B6","Unicodeshort":"U+1F3B6","Title":"musical notes"}},{"EmojiOne":{"Unicodelong":"\\U0001F496","Unicodeshort":"U+1F496","Title":"sparkling heart"},"EmojiTwo":{"Unicodelong":"\\U0001F495","Unicodeshort":"U+1F495","Title":"two hearts"}},{"EmojiOne":{"Unicodelong":"\\U0001F495","Unicodeshort":"U+1F495","Title":"two hearts"},"EmojiTwo":{"Unicodelong":"\\U0001F493","Unicodeshort":"U+1F493","Title":"beating heart"}},{"EmojiOne":{"Unicodelong":"\\U00002764","Unicodeshort":"U+2764","Title":"red heart"},"EmojiTwo":{"Unicodelong":"\\U0001F499","Unicodeshort":"U+1F499","Title":"blue heart"}},{"EmojiOne":{"Unicodelong":"\\U0001F499","Unicodeshort":"U+1F499","Title":"blue heart"},"EmojiTwo":{"Unicodelong":"\\U0001F49A","Unicodeshort":"U+1F49A","Title":"green heart"}},{"EmojiOne":{"Unicodelong":"\\U00002764","Unicodeshort":"U+2764","Title":"red heart"},"EmojiTwo":{"Unicodelong":"\\U0001F49C","Unicodeshort":"U+1F49C","Title":"purple heart"}},{"EmojiOne":{"Unicodelong":"\\U0001F49B","Unicodeshort":"U+1F49B","Title":"yellow heart"},"EmojiTwo":{"Unicodelong":"\\U0001F49A","Unicodeshort":"U+1F49A","Title":"green heart"}},{"EmojiOne":{"Unicodelong":"\\U00002764","Unicodeshort":"U+2764","Title":"red heart"},"EmojiTwo":{"Unicodelong":"\\U0001F496","Unicodeshort":"U+1F496","Title":"sparkling heart"}},{"EmojiOne":{"Unicodelong":"\\U00002764","Unicodeshort":"U+2764","Title":"red heart"},"EmojiTwo":{"Unicodelong":"\\U0001F49A","Unicodeshort":"U+1F49A","Title":"green heart"}},{"EmojiOne":{"Unicodelong":"\\U0001F49B","Unicodeshort":"U+1F49B","Title":"yellow heart"},"EmojiTwo":{"Unicodelong":"\\U00002764","Unicodeshort":"U+2764","Title":"red heart"}},{"EmojiOne":{"Unicodelong":"\\U0001F49C"," ...
// 5607 <nil>

// %%
if err = ioutil.WriteFile("emojisSim.json",jsonString,0755); err != nil{
    fmt.Println(err)
}
